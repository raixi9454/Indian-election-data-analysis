# %%
import pandas as pd
df=pd.read_csv("Indian_election_dataset.csv")
df.drop('pc_no',axis=1,inplace=True)
df.drop('partyabbre',axis=1,inplace=True)
df.drop_duplicates(inplace=True)
df.rename(columns={"st_name":"state","pc_name":"parliamentry_consituency","cand_sex":"cand_gender","partyname":"party_name","totvotpoll":"Total_Votes_Polled"},inplace=True)
df.rename(columns={"pc_type":"consituency_type"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73079 entries, 0 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     69496 non-null  object
#  1   year                      69396 non-null  float64
#  2   parliamentry_consituency  69548 non-null  object
#  3   consituency_type          61726 non-null  object
#  4   cand_name                 69475 non-null  object
#  5   cand_gender               68892 non-null  object
#  6   party_name                69507 non-null  object
#  7   Total_Votes_Polled        69509 non-null  float64
#  8   electors                  69340 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 5.6+ MB

# %%
df= df.dropna(subset=['Total_Votes_Polled', 'electors','cand_gender'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     59104 non-null  object
#  1   year                      59058 non-null  float64
#  2   parliamentry_consituency  59168 non-null  object
#  3   consituency_type          52398 non-null  object
#  4   cand_name                 59096 non-null  object
#  5   cand_gender               62146 non-null  object
#  6   party_name                59116 non-null  object
#  7   Total_Votes_Polled        62146 non-null  float64
#  8   electors                  62146 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 4.7+ MB

# %%
df['party_name'] = df['party_name'].fillna('Independent')
df['cand_name'] = df['cand_name'].fillna('Unknown')
df['consituency_type'] = df['consituency_type'].fillna(df['consituency_type'].mode()[0])
df['state'] = df['state'].fillna(df['state'].mode()[0])
df['year'] = df['year'].fillna(method='ffill')
df['cand_gender'] = df['cand_gender'].fillna('Unknown')
# Out:
# C:\Users\raisingh\AppData\Local\Temp\ipykernel_18828\2467147508.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['year'] = df['year'].fillna(method='ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     62146 non-null  object
#  1   year                      62146 non-null  float64
#  2   parliamentry_consituency  59168 non-null  object
#  3   consituency_type          62146 non-null  object
#  4   cand_name                 62146 non-null  object
#  5   cand_gender               62146 non-null  object
#  6   party_name                62146 non-null  object
#  7   Total_Votes_Polled        62146 non-null  float64
#  8   electors                  62146 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 4.7+ MB

# %%
df['parliamentry_consituency'] = df['parliamentry_consituency'].fillna(df['parliamentry_consituency'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     62146 non-null  object
#  1   year                      62146 non-null  float64
#  2   parliamentry_consituency  62146 non-null  object
#  3   consituency_type          62146 non-null  object
#  4   cand_name                 62146 non-null  object
#  5   cand_gender               62146 non-null  object
#  6   party_name                62146 non-null  object
#  7   Total_Votes_Polled        62146 non-null  float64
#  8   electors                  62146 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 4.7+ MB

# %%
df['cand_gender']=df['cand_gender'].astype("string")
df['cand_gender'] = df['cand_gender'].str.replace('M', 'Male')
df['cand_gender'] = df['cand_gender'].str.replace('F', 'Female')
df['cand_gender']=df['cand_gender'].str.replace('O','Other')

# %%
df['voter_turnout'] = (df['Total_Votes_Polled'] / df['electors']) * 100

# %%
df.drop('voter_turnout',axis=1,inplace=True)

# %%
df["year"]=df["year"].astype("int")
df['state']=df['state'].astype("string")
df["parliamentry_consituency"]=df["parliamentry_consituency"].astype("string")
df["party_name"]=df["party_name"].astype("string")
df["party_name"]=df["party_name"].astype("string")
df["consituency_type"]=df["consituency_type"].astype("string")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     62146 non-null  string
#  1   year                      62146 non-null  int64
#  2   parliamentry_consituency  62146 non-null  string
#  3   consituency_type          62146 non-null  string
#  4   cand_name                 62146 non-null  object
#  5   cand_gender               62146 non-null  string
#  6   party_name                62146 non-null  string
#  7   Total_Votes_Polled        62146 non-null  float64
#  8   electors                  62146 non-null  float64
# dtypes: float64(2), int64(1), object(1), string(5)
# memory usage: 4.7+ MB

# %%
df["cand_name"]=df["cand_name"].astype("string")
df["Total_Votes_Polled"]=df["Total_Votes_Polled"].astype("int")
df["electors"]=df["electors"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     62146 non-null  string
#  1   year                      62146 non-null  int64
#  2   parliamentry_consituency  62146 non-null  string
#  3   consituency_type          62146 non-null  string
#  4   cand_name                 62146 non-null  string
#  5   cand_gender               62146 non-null  string
#  6   party_name                62146 non-null  string
#  7   Total_Votes_Polled        62146 non-null  int64
#  8   electors                  62146 non-null  int64
#  9   voter_turnout             62146 non-null  float64
# dtypes: float64(1), int64(3), string(6)
# memory usage: 5.2 MB

# %%
df.to_csv('election clean dataset.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62146 entries, 1 to 73080
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     62146 non-null  string
#  1   year                      62146 non-null  int64
#  2   parliamentry_consituency  62146 non-null  string
#  3   consituency_type          62146 non-null  string
#  4   cand_name                 62146 non-null  string
#  5   cand_gender               62146 non-null  string
#  6   party_name                62146 non-null  string
#  7   Total_Votes_Polled        62146 non-null  int64
#  8   electors                  62146 non-null  int64
# dtypes: int64(3), string(6)
# memory usage: 4.7 MB
